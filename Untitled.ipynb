# %%
import pandas as pd

df=pd.DataFrame({
        "Name":["Affan","Hasher","Urooj","Laiba","Hassaan"],
        "Marks":[200,250,10,15,300],
        "Gender":["Male","Male","Female","Female","Male"],
        "School":["FDC","KamranAcademy","Educators","Iqra","Ilam"],
})

df
# Out:
#       Name  Marks  Gender         School
# 0    Affan    200    Male            FDC
# 1   Hasher    250    Male  KamranAcademy
# 2    Urooj     10  Female      Educators
# 3    Laiba     15  Female           Iqra
# 4  Hassaan    300    Male           Ilam

# %%
df.head(5)
# Out:
#       Name  Marks  Gender         School
# 0    Affan    200    Male            FDC
# 1   Hasher    250    Male  KamranAcademy
# 2    Urooj     10  Female      Educators
# 3    Laiba     15  Female           Iqra
# 4  Hassaan    300    Male           Ilam

# %%
df.shape
# Out:
# (5, 4)

# %%
df["Name"]
# Out:
# 0      Affan
# 1     Hasher
# 2      Urooj
# 3      Laiba
# 4    Hassaan
# Name: Name, dtype: object

# %%
df["School"]
# Out:
# 0              FDC
# 1    KamranAcademy
# 2        Educators
# 3             Iqra
# 4             Ilam
# Name: School, dtype: object

# %%
df[df["Marks"]>80]
# Out:
#       Name  Marks Gender         School
# 0    Affan    200   Male            FDC
# 1   Hasher    250   Male  KamranAcademy
# 4  Hassaan    300   Male           Ilam

# %%
Mean=df["Marks"].mean()
print(Mean)
# Out:
# 155.0

# %%
df=pd.DataFrame({
        "Name":["Affan","Hasher","Urooj","Laiba","Hassaan"],
        "Marks":[200,250,10,15,300],
        "Gender":["Male","Male","Female","Female","Male"],
        "School":["FDC","KamranAcademy","Educators","Iqra","Ilam"],
})

df=df.rename(columns={"Gender":"Males"})
df
# Out:
#       Name  Marks   Males         School
# 0    Affan    200    Male            FDC
# 1   Hasher    250    Male  KamranAcademy
# 2    Urooj     10  Female      Educators
# 3    Laiba     15  Female           Iqra
# 4  Hassaan    300    Male           Ilam

# %%
df["Marks"].values
# Out:
# array([200, 250,  10,  15, 300])

# %%
highest=0

for i in df["Marks"].values:
   if highest<i:
       highest=i

print("Highest Marks:",highest)
# Out:
# Highest Marks: 300

# %%
df=pd.DataFrame({
        "Name":["Affan","Hasher","Urooj","Laiba","Hassaan"],
        "Marks":[200,250,10,15,300],
        "Gender":["Male","Male","Female","Female","Male"],
        "School":["FDC","KamranAcademy","Educators","Iqra","Ilam"],
})

df["Class"]=[11,10,9,8,12]
df
# Out:
#       Name  Marks  Gender         School  Class
# 0    Affan    200    Male            FDC     11
# 1   Hasher    250    Male  KamranAcademy     10
# 2    Urooj     10  Female      Educators      9
# 3    Laiba     15  Female           Iqra      8
# 4  Hassaan    300    Male           Ilam     12

# %%
df=pd.DataFrame({
        "Name":["Affan","Hasher","Urooj","Laiba","Hassaan"],
        "Marks":[200,250,10,15,300],
        "Gender":["Male","Male","Female","Female","Male"],
        "School":["FDC","KamranAcademy","Educators","Iqra","Ilam"],
})

df.to_csv("file.csv",index=False)

df.iloc[-5:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.DataFrame({
#       2         "Name":["Affan","Hasher","Urooj","Laiba","Hassaan"],
#       3         "Marks":[200,250,10,15,300],
#       4         "Gender":["Male","Male","Female","Female","Male"],
#       5         "School":["FDC","KamranAcademy","Educators","Iqra","Ilam"],
#       6 })
#       8 df.to_csv("file.csv",index=False)
#      10 df
#
# NameError: name 'pd' is not defined
